# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/balloons/yellow-small.data")

# %%
df.head()
# Out:
#    YELLOW  SMALL  STRETCH  ADULT  T
# 0  YELLOW  SMALL  STRETCH  CHILD  T
# 1  YELLOW  SMALL      DIP  ADULT  T
# 2  YELLOW  SMALL      DIP  CHILD  T
# 3  YELLOW  SMALL  STRETCH  ADULT  T
# 4  YELLOW  SMALL  STRETCH  CHILD  T

# %%
df.tail()
# Out:
#     YELLOW  SMALL  STRETCH  ADULT  T
# 14  PURPLE  SMALL      DIP  CHILD  F
# 15  PURPLE  LARGE  STRETCH  ADULT  F
# 16  PURPLE  LARGE  STRETCH  CHILD  F
# 17  PURPLE  LARGE      DIP  ADULT  F
# 18  PURPLE  LARGE      DIP  CHILD  F

# %%
df.shape
# Out:
# (19, 5)

# %%
df.describe()
# Out:
#         YELLOW  SMALL STRETCH  ADULT   T
# count       19     19      19     19  19
# unique       2      2       2      2   2
# top     YELLOW  SMALL     DIP  CHILD   F
# freq        11     11      10     10  12

# %%
df.dtypes
# Out:
# YELLOW     object
# SMALL      object
# STRETCH    object
# ADULT      object
# T          object
# dtype: object

# %%
dhyey = pd.DataFrame({"Name": ["1", "22"], "Surname": ["3", "44"]})

# %%
dhyey.values
# Out:
# array([['1', '3'],
#        ['22', '44']], dtype=object)

# %%
df.head()
# Out:
#    YELLOW  SMALL  STRETCH  ADULT  T
# 0  YELLOW  SMALL  STRETCH  CHILD  T
# 1  YELLOW  SMALL      DIP  ADULT  T
# 2  YELLOW  SMALL      DIP  CHILD  T
# 3  YELLOW  SMALL  STRETCH  ADULT  T
# 4  YELLOW  SMALL  STRETCH  CHILD  T

# %%
Input_Color = df.drop(columns = ['T'])

# %%
Predicted_Ouput = df['ADULT']

# %%
df.loc[df['YELLOW'] == 'PURPLE', ['ADULT']]
# Out:
#     ADULT
# 11  ADULT
# 12  CHILD
# 13  ADULT
# 14  CHILD
# 15  ADULT
# 16  CHILD
# 17  ADULT
# 18  CHILD

# %%
df[df["YELLOW"].isin(["PURPLE"])]
# Out:
#     YELLOW  SMALL  STRETCH  ADULT  T
# 11  PURPLE  SMALL  STRETCH  ADULT  F
# 12  PURPLE  SMALL  STRETCH  CHILD  F
# 13  PURPLE  SMALL      DIP  ADULT  F
# 14  PURPLE  SMALL      DIP  CHILD  F
# 15  PURPLE  LARGE  STRETCH  ADULT  F
# 16  PURPLE  LARGE  STRETCH  CHILD  F
# 17  PURPLE  LARGE      DIP  ADULT  F
# 18  PURPLE  LARGE      DIP  CHILD  F

# %%
df.sort_values(by = ["SMALL"], ascending = [False])
# Out:
#     level_0  index  YELLOW  SMALL  STRETCH  ADULT  T
# 0         0      0  YELLOW  SMALL  STRETCH  CHILD  T
# 14       14     14  PURPLE  SMALL      DIP  CHILD  F
# 2         2      2  YELLOW  SMALL      DIP  CHILD  T
# 3         3      3  YELLOW  SMALL  STRETCH  ADULT  T
# 4         4      4  YELLOW  SMALL  STRETCH  CHILD  T
# 5         5      5  YELLOW  SMALL      DIP  ADULT  T
# 6         6      6  YELLOW  SMALL      DIP  CHILD  T
# 1         1      1  YELLOW  SMALL      DIP  ADULT  T
# 11       11     11  PURPLE  SMALL  STRETCH  ADULT  F
# 12       12     12  PURPLE  SMALL  STRETCH  CHILD  F
# 13       13     13  PURPLE  SMALL      DIP  ADULT  F
# 17       17     17  PURPLE  LARGE      DIP  ADULT  F
# 16       16     16  PURPLE  LARGE  STRETCH  CHILD  F
# 15       15     15  PURPLE  LARGE  STRETCH  ADULT  F
# 9         9      9  YELLOW  LARGE      DIP  ADULT  F
# 10       10     10  YELLOW  LARGE      DIP  CHILD  F
# 8         8      8  YELLOW  LARGE  STRETCH  CHILD  F
# ...
